# %% [markdown]
# # Creating a Neural network that takes two inputs, has one hidden layer with two nodes, and an output layer with one node.

# %%
from IPython.display import Image
Image("/home/adarshrana205/Desktop/neural_network_example.png")
#Link for below image:("http://cocl.us/neural_network_example")

# %%
import numpy as np 

weights = np.around(np.random.uniform(size=6), decimals=2) 
biases = np.around(np.random.uniform(size=3), decimals=2)

# %%
print(weights)
# Out:
# [0.52 0.02 0.07 0.86 0.03 0.74]

# %%
print(biases)
# Out:
# [0.55 0.89 0.71]

# %%
x_1 = 0.5 
x_2 = 0.85 
print('x1 is {} and x2 is {}'.format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %%
z_11=x_1*weights[0]+x_2*weights[1]+biases[0]

print('The weighted sum of the inputs at the first node in the hidden layer is {}'.format(z_11))
# Out:
# The weighted sum of the inputs at the first node in the hidden layer is 0.8270000000000001

# %%
z_12=x_1*weights[2]+x_2*weights[3]+biases[1]

print('The weighted sum of the inputs at the second node in the hidden layer is {}'.format(np.around(z_12, decimals=4)))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 1.656

# %%
a_11 = 1.0 / (1.0 + np.exp(-z_11))

print('The activation of the first node in the hidden layer is {}'.format(np.around(a_11, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.6957

# %%
a_12 = 1.0 / (1.0 + np.exp(-z_12))

print('The activation of the second node in the hidden layer is {}'.format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.8397

# %%
z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]

print('The weighted sum of the inputs at the node in the output layer is {}'.format(np.around(z_2, decimals=4)))
# Out:
# The weighted sum of the inputs at the node in the output layer is 1.3522

# %%
a_2 = 1.0 / (1.0 + np.exp(-z_2))

print('The output of the network for x1 = 0.5 and x2 = 0.85 is {}'.format(np.around(a_2, decimals=4)))
# Out:
# The output of the network for x1 = 0.5 and x2 = 0.85 is 0.7945

# %% [markdown]
# ### General neural network which would take 𝑛 inputs, would have many hidden layers, each hidden layer having 𝑚 nodes, and would have an output layer.So, we can't continue making predictions using this very inefficient approach of computing the weighted sum at each node and the activation of each node manually.In order to code an automatic way of making predictions, let's generalize our network.

# %%
from IPython.display import Image
Image("/home/adarshrana205/Desktop/neural_network_general.png")
#Link for below image:("http://cocl.us/general_neural_network")
